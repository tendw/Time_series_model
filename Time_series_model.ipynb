# %%
# импорт библиотек
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error, mean_squared_error

sns.set_style("darkgrid")

# %matplotlib inline

# %% [markdown]
# # Разведочный анализ данных

# %%
# загружаем датасет
df = pd.read_csv(
    'Период отчета_01.01.2018_31.12.2022_раздел.csv',
    index_col = [0], # преобразуем столбец с датой в индекс
    parse_dates = [0], # преобразуем дату в формат datetime
    dayfirst = True) # уточняем, что день идет первым

# %%
# копируем датасет и выводим первые пять строк
df_sales = df.copy()
print(df_sales.shape)
df_sales.head()
# Out:
# (4102457, 8)
#                              Shop          Nomenclature_group  \
# Date
# 2018-01-02  (закрыт) ЭНЕРГЕТИКОВ         Арматура для унитаза
# 2018-01-02  (закрыт) ЭНЕРГЕТИКОВ   Канализация, сифоны, гофры
# 2018-01-02  (закрыт) ЭНЕРГЕТИКОВ                    Смесители
# 2018-01-02           БАЙКОНУРСКАЯ        Арматура для унитаза
# 2018-01-02           БАЙКОНУРСКАЯ            Воздухоотводчики
#
#                                                  Nomenclature  Quantity_sold  \
# Date
# 2018-01-02     Механизм впускной 1/2 боковой ALCAPLAST А-15,               1
# 2018-01-02  Клапан Bonomini обратный для стиральной машины...              1
# 2018-01-02  Смеситель для ванны MOFEM Треф  603 TREFF CER ...              1
# 2018-01-02  Механизм впускной 1/2 нижний ALCAPLAST А-17 , ...              1
# 2018-01-02                          Кран воздушный КВ-1, 3/4"              4
#
#             Cost_price  Revenue  Profit  Profit_percent
# Date
# 2018-01-02         251      452     201           79.78
# 2018-01-02         146      224      78           53.30
# 2018-01-02        3605     5488    1883           52.25
# 2018-01-02         290      534     244           84.27
# 2018-01-02         119      252     133          111.71

# %%
# смотрим пропуски
df_sales.isna().sum()
# Out:
# Shop                  11
# Nomenclature_group     3
# Nomenclature           0
# Quantity_sold          0
# Cost_price             0
# Revenue                0
# Profit                 0
# Profit_percent         0
# dtype: int64

# %%
# выводим описательную статитстику
df_sales.describe()
# Out:
#        Quantity_sold    Cost_price       Revenue        Profit  Profit_percent
# count   4.102457e+06  4.102457e+06  4.102457e+06  4.102457e+06    4.102457e+06
# mean    4.054585e+00  6.475682e+02  9.200173e+02  2.724711e+02    1.558719e+02
# std     1.749061e+01  2.591071e+03  4.266126e+03  2.423863e+03    1.173645e+04
# min    -1.500000e+03 -2.038840e+05 -6.529940e+05 -6.529940e+05   -1.932130e+03
# 25%     1.000000e+00  5.900000e+01  1.040000e+02  4.200000e+01    5.674000e+01
# 50%     2.000000e+00  1.700000e+02  2.920000e+02  1.170000e+02    7.065000e+01
# 75%     4.000000e+00  4.710000e+02  7.950000e+02  3.150000e+02    8.667000e+01
# max     1.200000e+04  1.168608e+06  1.579200e+06  4.127990e+05    4.999900e+06

# %%
# топ продаж по номенклатуре
#df_sales['Nomenclature'].value_counts().head(10)
# Out:
# Услуги по оформлению документов,                        35505
# Пакет п/э (40*60),                                      32742
# Ниппель , Диаметр: 1/2                                  26057
# Отвод Ostendorf, 50мм х 45°                             21992
# Отвод Ostendorf, 50мм х 87°                             21612
# Труба металлопластиковая HENCO Стандарт, Диаметр: 16    21555
# Труба фановая Ostendorf, 50мм х 500мм                   19788
# Гофра Jimten A-103, Диаметр: 1-1/2, Размер: 50          19308
# Труба фановая Ostendorf, 50мм х 1000мм                  17844
# Труба металлопластиковая HENCO Стандарт, Диаметр: 20    16459
# Name: Nomenclature, dtype: int64

# %%
# топ продаж по магазинам
#df_sales['Shop'].value_counts().head(10)
# Out:
# ГАГАРИНА              315729
# ВЫБОРГСКОЕ ШОССЕ      288133
# В О 15 линия, д.72    285925
# ЛЕНИНА                237012
# ВСЕВОЛОЖСК            236860
# ПУШКИН                210113
# ОБУХОВСКОЙ_ОБОРОНЫ    208536
# РАЗЪЕЗЖАЯ             207698
# РУДНЕВА               195030
# ЛАНСКОЕ               190185
# Name: Shop, dtype: int64

# %%
# берем продажи одной товарной позиции и(или) магазина

#df_sales = df_sales.loc[df_sales['Shop'] == 'ГАГАРИНА']
#df_sales = df_sales.loc[df_sales['Nomenclature'] == 'Отвод Ostendorf, 50мм х 45°']
#print(df_sales.shape)
#df_sales.head()

# %%
# изменяем шаг временного ряда, берем сумму (sum) или среднее (mean) за неделю

df_sales = df_sales[['Profit']].resample('W').sum()
print(df_sales.shape)
df_sales.head()
# Out:
# (261, 1)
#              Profit
# Date
# 2018-01-07   805551
# 2018-01-14  1997174
# 2018-01-21  2566781
# 2018-01-28  2894793
# 2018-02-04  3019153

# %%
# строим график временного ряда
plt.figure(figsize=(8,4))
plt.plot(df_sales)
plt.title('Прибыль с 2018 по 2022 года (по неделям)')
plt.xlabel('Период')
plt.ylabel('Сумма')
plt.show()

# %%
# строим гистограмму 
plt.figure(figsize=(8,4))
sns.histplot(df_sales, bins = 60)
plt.show()

# %%
# строим boxplot 
plt.figure(figsize=(8,4))
sns.boxplot(x = df_sales.Profit)
plt.show()

# %%
# заменяем выбросы средним значением по неделям

Q1 = df_sales['Profit'].quantile(0.25)
Q3 = df_sales['Profit'].quantile(0.75)
IQR = Q3 - Q1
df_Q1 = np.array(df_sales[(df_sales['Profit'] < Q1-1.5*IQR )])
df_Q3 = np.array(df_sales[(df_sales['Profit'] > Q3+1.5*IQR )])

df_2018 = df_sales['2018':'2018']['Profit']
df_2019 = df_sales['2019':'2019']['Profit']
df_2020 = df_sales['2020':'2020']['Profit']
df_2021 = df_sales['2021':'2021']['Profit']
df_2022 = df_sales['2022':'2022']['Profit']

for i in range(len(df_sales)):
    if (df_sales.values[i] == df_Q1).any() or (df_sales.values[i] == df_Q3).any():
        index = (df_sales.index[i])
        df_list = [df_2018[(df_sales.index[i].week)-1],
                   df_2019[(df_sales.index[i].week)-1],
                   df_2020[(df_sales.index[i].week)-1],
                   df_2021[(df_sales.index[i].week)-1],
                   df_2022[(df_sales.index[i].week)-1]]

        df_sales[index:index] = np.mean(df_list)

# %% [markdown]
# # LinearRegression

# %%
def prepareData(data, lag_start=1, lag_end=4, test_size=0.1):

    data = pd.DataFrame(data.copy())
    data.columns = ["y"]

    # считаем индекс в датафрейме, после которого начинается тестовыый отрезок
    test_index = int(len(data)*(1-test_size))

    # добавляем лаги исходного ряда в качестве признаков
    for i in range(lag_start, lag_end):
        data["lag_{}".format(i)] = data.y.shift(i)

    y = data.dropna().y
    X = data.dropna().drop(['y'], axis=1)

    # разбиваем весь датасет на тренировочную и тестовую выборку
    X_train = X.iloc[:test_index]
    y_train = y.iloc[:test_index]
    X_test = X.iloc[test_index:]
    y_test = y.iloc[test_index:]

    return X_train, X_test, y_train, y_test

# %%
from sklearn.linear_model import LinearRegression

X_train, X_test, y_train, y_test = prepareData(df_sales, lag_start=1, lag_end=4, test_size=0.1)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

lr = LinearRegression()
lr.fit(X_train, y_train)

lr_pred = lr.predict(X_test)

df_lr_pred = pd.DataFrame(data=y_test)
df_lr_pred['prediction'] = lr_pred
print(df_lr_pred.shape)
df_lr_pred.sample(5).round()
# Out:
# (234, 3) (24, 3) (234,) (24,)
# (24, 2)
#                     y  prediction
# Date
# 2022-09-18  5641971.0   5153019.0
# 2022-11-13  3957250.0   3937417.0
# 2023-01-01  4012988.0   3926330.0
# 2022-07-24  4858085.0   5327003.0
# 2022-10-02  4944717.0   5024783.0

# %%
plt.figure(figsize=(8,4))
plt.plot(y_train, label='y_train')
plt.plot(df_lr_pred['y'], label='y_test')
plt.plot(df_lr_pred['prediction'], color='b', label='prediction')
    
error_lr = mean_absolute_error(df_lr_pred['prediction'], df_lr_pred['y'])
plt.title("LinearRegression MAE {0:.0f}".format(error_lr))
plt.legend(loc="best")
plt.show()

# %% [markdown]
# # RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

base_rf = RandomForestRegressor(random_state=42)
base_rf.fit(X_train, y_train)

pred_rf = base_rf.predict(X_test)

# %%
df_rf = pd.DataFrame(data=y_test)
df_rf['prediction'] = pred_rf
df_rf.sample(5).round()
# Out:
#                     y  prediction
# Date
# 2022-10-02  4944717.0   4977288.0
# 2022-11-13  3957250.0   3877742.0
# 2022-07-24  4858085.0   5735267.0
# 2022-07-31  5757894.0   5101871.0
# 2022-11-20  3809051.0   4114816.0

# %%
plt.figure(figsize=(8,4))
plt.plot(y_train, label='y_train')
plt.plot(df_rf['y'], label='y_test')
plt.plot(df_rf['prediction'], color='b', label='prediction')
    
error_rf = mean_absolute_error(df_rf['prediction'], df_rf['y'])
plt.title("RandomForestRegressor MAE {0:.0f}".format(error_rf))
plt.legend(loc="best")
plt.show()

# %%
from pprint import pprint
print('параметры по умолчанию:\n')
pprint(base_rf.get_params())
# Out:
# параметры по умолчанию:
#
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': 42,
#  'verbose': 0,
#  'warm_start': False}

# %%
from sklearn.model_selection import GridSearchCV
# Создаем сетку параметров
param_grid = { 
    'bootstrap': [True, False],
    'max_depth': [2, 4, 6, 8, 10], 
    'max_features': [1, 2, 3], 
    'min_samples_leaf' : [1, 2, 3], 
    'min_samples_split': [2, 4, 6], 
    'n_estimators': [100, 200, 300] 
}
# Создаем модель
rf = RandomForestRegressor()
# Создание модели поиска по сетке 
grid_search = GridSearchCV(estimator = rf, param_grid = param_grid, cv = 3, n_jobs=-1)

# %%
# Сопоставим поиск по сетке с данными 
grid_search.fit(X_train, y_train)
grid_search.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 2,
#  'max_features': 3,
#  'min_samples_leaf': 3,
#  'min_samples_split': 2,
#  'n_estimators': 300}

# %%
best_grid = grid_search.best_estimator_
best_grid_pred = best_grid.predict(X_test)

df_rf_grid = pd.DataFrame(data=y_test)
df_rf_grid['prediction'] = best_grid_pred
df_rf_grid.tail().round()
# Out:
#                     y  prediction
# Date
# 2022-12-04  4103560.0   3984990.0
# 2022-12-11  3973320.0   3992469.0
# 2022-12-18  3652897.0   3929997.0
# 2022-12-25  3933966.0   3727838.0
# 2023-01-01  4012988.0   3876199.0

# %%
plt.figure(figsize=(8,4))
plt.plot(y_train, label='y_train')
plt.plot(df_rf_grid['y'], label='y_test')
plt.plot(df_rf_grid['prediction'], color='b', label='prediction')
    
error_rf = mean_absolute_error(df_rf_grid['prediction'], df_rf_grid['y'])
plt.title("RandomForestRegressor MAE {0:.0f}".format(error_rf))
plt.legend(loc="best")
plt.show()

# %% [markdown]
# # XGBoost

# %%
import xgboost as xgb

# исходные данные
X_train, X_test, y_train, y_test = prepareData(df_sales, lag_start=1, lag_end=4, test_size=0.1)
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test)

# задаём параметры
params = {
        'objective': 'reg:squarederror',
        'booster':'gblinear'
         }

trees = 1000

# прогоняем на кросс-валидации с метрикой rmse
cv = xgb.cv(params, dtrain, metrics = ('rmse'), verbose_eval=False, nfold=10, show_stdv=False, num_boost_round=trees)

# обучаем xgboost с оптимальным числом деревьев, подобранным на кросс-валидации
bst = xgb.train(params, dtrain, num_boost_round=cv['test-rmse-mean'].argmin())

# запоминаем ошибку на кросс-валидации
deviation = cv.loc[cv['test-rmse-mean'].argmin()]["test-rmse-mean"]

# %%
prediction_test = bst.predict(dtest)

df_xgb = pd.DataFrame(data=y_test)
df_xgb['prediction'] = prediction_test
df_xgb.sample(5).round()
# Out:
#                     y  prediction
# Date
# 2022-09-04  5048385.0   4707792.0
# 2022-07-24  4858085.0   5354158.0
# 2022-10-23  4258251.0   4727750.0
# 2022-11-13  3957250.0   3968636.0
# 2022-08-21  4685013.0   4707336.0

# %%
plt.figure(figsize=(8, 4))
plt.plot(y_train, label='y_train')
plt.plot(df_xgb['y'], label='y_test')
plt.plot(df_xgb['prediction'], color='b', label='prediction')

error_xgb = mean_absolute_error(df_xgb['prediction'], df_xgb['y'])
plt.title("XGBoost MAE {0:.0f}".format(error_xgb))
plt.legend(loc="best")
plt.show()

# %%
print("LinearRegression MAE {0:.0f}\n".format(error_lr))
print("RandomForestRegressor MAE {0:.0f}\n".format(error_rf))
print("XGBoost MAE {0:.0f}".format(error_xgb))
# Out:
# LinearRegression MAE 330505
#
# RandomForestRegressor MAE 357806
#
# XGBoost MAE 331693

# %% [markdown]
# # Нейронная сеть

# %%
import tensorflow as tf

tf.random.set_seed(42)
# Out:
# 2023-04-29 11:40:37.022039: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i)
        # Изменить форму данных с (history_size,) на (history_size, 1)
        data.append(np.reshape(dataset[indices], (history_size, 1)))
        labels.append(dataset[i+target_size])
    return np.array(data), np.array(labels)

# %%
def create_time_steps(length):
    return list(range(-length, 0))

# %%
def show_plot(plot_data, delta, title):
    labels = ['История', 'Реальное будущее значение', 'Прогноз']
    marker = ['o-', 'o', 'rx']
    time_steps = create_time_steps(plot_data[0].shape[0])
    if delta:
      future = delta
    else:
      future = 0
  
    plt.figure(figsize=(8,4))
    plt.title(title)
    for i, x in enumerate(plot_data):
      if i:
        plt.plot(future, plot_data[i], marker[i], markersize=7,
                 label=labels[i])
      else:
        plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
    plt.legend()
    plt.xlim([time_steps[0], (future+5)*2])
    plt.xlabel('Временной интервал')
    return plt.show()

# %%
def plot_loss(history):
    plt.figure(figsize=(8, 4))
    plt.plot(history.history['loss'], '.--', label='loss')
    plt.plot(history.history['val_loss'], 'o-', label='val_loss')
    plt.xlabel('Эпоха')
    plt.ylabel('MAE')
    plt.legend()
    plt.show()

# %%
# добавляем лаги исходного ряда в качестве признаков
data = df_sales.copy()
data.columns = ["y"]
    
for i in range(1, 4):
    data["lag_{}".format(i)] = data.y.shift(i)

data = data.dropna()
print(data.shape)
data.head()
# Out:
# (258, 4)
#                     y      lag_1      lag_2      lag_3
# Date
# 2018-01-28  2894793.0  2566781.0  1997174.0  2029539.4
# 2018-02-04  3019153.0  2894793.0  2566781.0  1997174.0
# 2018-02-11  2808985.0  3019153.0  2894793.0  2566781.0
# 2018-02-18  2706368.0  2808985.0  3019153.0  2894793.0
# 2018-02-25  2313516.0  2706368.0  2808985.0  3019153.0

# %%
uni_data = data[['y']]
print(uni_data.shape)
uni_data.head()
# Out:
# (258, 1)
#                     y
# Date
# 2018-01-28  2894793.0
# 2018-02-04  3019153.0
# 2018-02-11  2808985.0
# 2018-02-18  2706368.0
# 2018-02-25  2313516.0

# %%
uni_data = uni_data.values
print(uni_data.shape)
uni_data[:5]
# Out:
# (258, 1)
# array([[2894793.],
#        [3019153.],
#        [2808985.],
#        [2706368.],
#        [2313516.]])

# %%
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler()
uni_data = mm.fit_transform(uni_data)
print(uni_data.shape)
uni_data[:5]
# Out:
# (258, 1)
# array([[0.27061214],
#        [0.293512  ],
#        [0.2548113 ],
#        [0.23591523],
#        [0.16357477]])

# %%
n = len(uni_data)

uni_train_mean = uni_data[:int(n*0.85)].mean()
uni_train_std = uni_data[:int(n*0.85)].std()

uni_data = (uni_data - uni_train_mean) / uni_train_std

print(uni_data.shape)
uni_data[:5]
# Out:
# (258, 1)
# array([[-0.99364904],
#        [-0.87615926],
#        [-1.0747166 ],
#        [-1.17166456],
#        [-1.54281358]])

# %%
n = len(uni_data)

uni_data = (uni_data * uni_train_std) + uni_train_mean

print(uni_data.shape)
uni_data[:5]
# Out:
# (259, 1)
# array([[2566781.],
#        [2894793.],
#        [3019153.],
#        [2808985.],
#        [2706368.]])

# %%
n = len(uni_data)

univariate_past_history = 21
univariate_future_target = 0

x_train, y_train = univariate_data(uni_data, 0, int(n*0.9),
                                           univariate_past_history,
                                           univariate_future_target)
x_val, y_val = univariate_data(uni_data, int(n*0.9), None,
                                       univariate_past_history,
                                       univariate_future_target)

x_train.shape, y_train.shape, x_val.shape, y_val.shape
# Out:
# ((211, 21, 1), (211, 1), (5, 21, 1), (5, 1))

# %%
print ('История:\n')
print (x_train[0])
print ('\nЦель для прогнозирования:\n')
print (y_train[0])
# Out:
# История:
#
# [[0.27061214]
#  [0.293512  ]
#  [0.2548113 ]
#  [0.23591523]
#  [0.16357477]
#  [0.2394502 ]
#  [0.14036389]
#  [0.25830373]
#  [0.29157023]
#  [0.28602646]
#  [0.28281226]
#  [0.2797905 ]
#  [0.35415338]
#  [0.42526266]
#  [0.14913935]
#  [0.24844442]
#  [0.44876339]
#  [0.506297  ]
#  [0.45261563]
#  [0.51024942]
#  [0.36066611]]
#
# Цель для прогнозирования:
#
# [0.43962259]

# %%
for col in range(3):
    show_plot(
              [x_train[col],
               y_train[col]],
               0,
               'Пример с выборкой'
               )
plt.show()

# %%
simple_lstm = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(16, input_shape=x_train.shape[-2:]),
    tf.keras.layers.Dense(1)
])

simple_lstm.compile(optimizer=tf.optimizers.Adam(learning_rate=0.1), loss='mean_absolute_error')
simple_lstm.summary()
# Out:
# 2023-04-29 11:41:12.899365: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-29 11:41:12.900212: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 16)                1152
#
#  dense (Dense)               (None, 1)                 17
#
# =================================================================
# Total params: 1,169
# Trainable params: 1,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = simple_lstm.fit(x_train, 
                          y_train, 
                          epochs=16, 
                          validation_data=(x_val, y_val))
# Out:
# Epoch 1/16
# 7/7 [==============================] - 3s 117ms/step - loss: 0.3091 - val_loss: 0.0435
# Epoch 2/16
# 7/7 [==============================] - 0s 20ms/step - loss: 0.1441 - val_loss: 0.0917
# Epoch 3/16
# 7/7 [==============================] - 0s 16ms/step - loss: 0.1268 - val_loss: 0.0789
# Epoch 4/16
# 7/7 [==============================] - 0s 14ms/step - loss: 0.1203 - val_loss: 0.0239
# Epoch 5/16
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0958 - val_loss: 0.0268
# Epoch 6/16
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0965 - val_loss: 0.0366
# Epoch 7/16
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0896 - val_loss: 0.0331
# Epoch 8/16
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0862 - val_loss: 0.0409
# Epoch 9/16
# 7/7 [==============================] - 0s 15ms/step - loss: 0.1007 - val_loss: 0.0453
# Epoch 10/16
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0955 - val_loss: 0.0738
# Epoch 11/16
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0927 - val_loss: 0.0883
# Epoch 12/16
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0954 - val_loss: 0.0791
# Epoch 13/16
# 7/7 [==============================] - 0s 14ms/step - loss: 0.0938 - val_loss: 0.0594
# Epoch 14/16
# 7/7 [==============================] - 0s 17ms/step - loss: 0.0978 - val_loss: 0.0274
# Epoch 15/16
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0902 - val_loss: 0.0262
# Epoch 16/16
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0892 - val_loss: 0.0290

# %%
plot_loss(history)

# %%
y_pred_basic = simple_lstm.predict(x_val)

print(mean_absolute_error(mm.inverse_transform(y_val), mm.inverse_transform(y_pred_basic)))
# Out:
# 1/1 [==============================] - 0s 478ms/step
# 157452.7000000001

# %%
for col in range(3):
    show_plot([x_val[col], 
               y_val[col], 
               y_pred_basic[col]], 
               0, 
               'Простая LSTM модель')
plt.show()

# %%
# добавляем лаги исходного ряда в качестве признаков
data = df_sales.copy()
data.columns = ["y"]
    
for i in range(1, 3):
    data["lag_{}".format(i)] = data.y.shift(i)

data = data.dropna()
data.head()
# Out:
#                     y      lag_1      lag_2
# Date
# 2018-01-21  2566781.0  1997174.0  2029539.4
# 2018-01-28  2894793.0  2566781.0  1997174.0
# 2018-02-04  3019153.0  2894793.0  2566781.0
# 2018-02-11  2808985.0  3019153.0  2894793.0
# 2018-02-18  2706368.0  2808985.0  3019153.0

# %%
uni_data = data.values
print(uni_data.shape)
uni_data[:5]
# Out:
# (259, 3)
# array([[2566781. , 1997174. , 2029539.4],
#        [2894793. , 2566781. , 1997174. ],
#        [3019153. , 2894793. , 2566781. ],
#        [2808985. , 3019153. , 2894793. ],
#        [2706368. , 2808985. , 3019153. ]])

# %%
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler()
uni_data = mm.fit_transform(uni_data)
print(uni_data.shape)
uni_data[:5]
# Out:
# (259, 3)
# array([[0.21021143, 0.105323  , 0.11128283],
#        [0.27061214, 0.21021143, 0.105323  ],
#        [0.293512  , 0.27061214, 0.21021143],
#        [0.2548113 , 0.293512  , 0.27061214],
#        [0.23591523, 0.2548113 , 0.293512  ]])

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

# %%
n = len(uni_data)

past_history = 28
future_target = 3
STEP = 1

x_train_single, y_train_single = multivariate_data(uni_data, uni_data[:, 0], 0,
                                                   int(n*0.85), past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(uni_data, uni_data[:, 0],
                                               int(n*0.85), None, past_history,
                                               future_target, STEP,
                                               single_step=True)

x_train_single.shape, y_train_single.shape, x_val_single.shape, y_val_single.shape
# Out:
# ((192, 28, 3), (192,), (8, 28, 3), (8,))

# %%
print ('История:\n')
print (x_train_single[0])
print ('\nЦель для прогноза:\n')
print (y_train_single[0])
# Out:
# История:
#
# [[0.21021143 0.105323   0.11128283]
#  [0.27061214 0.21021143 0.105323  ]
#  [0.293512   0.27061214 0.21021143]
#  [0.2548113  0.293512   0.27061214]
#  [0.23591523 0.2548113  0.293512  ]
#  [0.16357477 0.23591523 0.2548113 ]
#  [0.2394502  0.16357477 0.23591523]
#  [0.14036389 0.2394502  0.16357477]
#  [0.25830373 0.14036389 0.2394502 ]
#  [0.29157023 0.25830373 0.14036389]
#  [0.28602646 0.29157023 0.25830373]
#  [0.28281226 0.28602646 0.29157023]
#  [0.2797905  0.28281226 0.28602646]
#  [0.35415338 0.2797905  0.28281226]
#  [0.42526266 0.35415338 0.2797905 ]
#  [0.14913935 0.42526266 0.35415338]
#  [0.24844442 0.14913935 0.42526266]
#  [0.44876339 0.24844442 0.14913935]
#  [0.506297   0.44876339 0.24844442]
#  [0.45261563 0.506297   0.44876339]
#  [0.51024942 0.45261563 0.506297  ]
#  [0.36066611 0.51024942 0.45261563]
#  [0.43962259 0.36066611 0.51024942]
#  [0.51288504 0.43962259 0.36066611]
#  [0.52761491 0.51288504 0.43962259]
#  [0.40945299 0.52761491 0.51288504]
#  [0.46402413 0.40945299 0.52761491]
#  [0.46647561 0.46402413 0.40945299]]
#
# Цель для прогноза:
#
# 0.4073550634101321

# %%
for col in range(3):
    show_plot(
              [x_train_single[col][:,0],
               y_train_single[col]],
               3,
               'Пример с выборкой'
               )
plt.show()

# %%
single_step_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(32, input_shape=x_train_single.shape[-2:]),
    tf.keras.layers.Dense(1)
])

single_step_model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.1), loss='mean_absolute_error')
single_step_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 32)                4608
#
#  dense_1 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4,641
# Trainable params: 4,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
single_step_history = single_step_model.fit(x_train_single,
                                            y_train_single,
                                            epochs=16,
                                            validation_data=(x_val_single, y_val_single))
# Out:
# Epoch 1/16
# 6/6 [==============================] - 3s 175ms/step - loss: 1.1118 - val_loss: 0.1983
# Epoch 2/16
# 6/6 [==============================] - 0s 31ms/step - loss: 0.1797 - val_loss: 0.0267
# Epoch 3/16
# 6/6 [==============================] - 0s 35ms/step - loss: 0.1429 - val_loss: 0.0521
# Epoch 4/16
# 6/6 [==============================] - 0s 50ms/step - loss: 0.1866 - val_loss: 0.0627
# Epoch 5/16
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1298 - val_loss: 0.0343
# Epoch 6/16
# 6/6 [==============================] - 0s 39ms/step - loss: 0.1167 - val_loss: 0.0712
# Epoch 7/16
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1184 - val_loss: 0.0514
# Epoch 8/16
# 6/6 [==============================] - 1s 120ms/step - loss: 0.1131 - val_loss: 0.0773
# Epoch 9/16
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1089 - val_loss: 0.1229
# Epoch 10/16
# 6/6 [==============================] - 0s 43ms/step - loss: 0.1169 - val_loss: 0.1046
# Epoch 11/16
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1171 - val_loss: 0.0361
# Epoch 12/16
# 6/6 [==============================] - 0s 58ms/step - loss: 0.1106 - val_loss: 0.0870
# Epoch 13/16
# 6/6 [==============================] - 0s 78ms/step - loss: 0.1199 - val_loss: 0.0414
# Epoch 14/16
# 6/6 [==============================] - 0s 48ms/step - loss: 0.1177 - val_loss: 0.0668
# Epoch 15/16
# 6/6 [==============================] - 0s 45ms/step - loss: 0.1173 - val_loss: 0.1029
# Epoch 16/16
# 6/6 [==============================] - 0s 40ms/step - loss: 0.1106 - val_loss: 0.1493

# %%
plot_loss(single_step_history)

# %%
y_pred_step = single_step_model.predict(x_val_single)

#print(mean_absolute_error(mm.inverse_transform(y_val_single.reshape(-1,1)), mm.inverse_transform(y_pred_step)))
# Out:
# 1/1 [==============================] - 0s 409ms/step

# %%
for col in range(3):
    show_plot([x_val_single[col][:,0], 
               y_val_single[col], 
               y_pred_step[col]], 
               3, 
               'Точечное погнозирование')
plt.show()

# %%
# добавляем лаги исходного ряда в качестве признаков
data = df_sales.copy()
data.columns = ["y"]
    
for i in range(1, 3):
    data["lag_{}".format(i)] = data.y.shift(i)

data = data.dropna()
data.head()
# Out:
#                     y      lag_1      lag_2
# Date
# 2018-01-21  2566781.0  1997174.0  2029539.4
# 2018-01-28  2894793.0  2566781.0  1997174.0
# 2018-02-04  3019153.0  2894793.0  2566781.0
# 2018-02-11  2808985.0  3019153.0  2894793.0
# 2018-02-18  2706368.0  2808985.0  3019153.0

# %%
uni_data = data.values
print(uni_data.shape)
uni_data[:5]
# Out:
# (259, 3)
# array([[2566781. , 1997174. , 2029539.4],
#        [2894793. , 2566781. , 1997174. ],
#        [3019153. , 2894793. , 2566781. ],
#        [2808985. , 3019153. , 2894793. ],
#        [2706368. , 2808985. , 3019153. ]])

# %%
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler()
uni_data = mm.fit_transform(uni_data)
print(uni_data.shape)
uni_data[:5]
# Out:
# (259, 3)
# array([[0.21021143, 0.105323  , 0.11128283],
#        [0.27061214, 0.21021143, 0.105323  ],
#        [0.293512  , 0.27061214, 0.21021143],
#        [0.2548113 , 0.293512  , 0.27061214],
#        [0.23591523, 0.2548113 , 0.293512  ]])

# %%
n = len(uni_data)

past_history = 28
future_target = 7
STEP = 1

x_train_multi, y_train_multi = multivariate_data(uni_data, uni_data[:, 0], 0,
                                                 int(n*0.85), past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(uni_data, uni_data[:, 0],
                                             int(n*0.85), None, past_history,
                                             future_target, STEP)

x_train_multi.shape, y_train_multi.shape, x_val_multi.shape, y_val_multi.shape
# Out:
# ((192, 28, 3), (192, 7), (4, 28, 3), (4, 7))

# %%
print ('История : {}'.format(x_train_multi[0].shape))
print ('\nЦель для прогнозирования : {}'.format(y_train_multi[0].shape))
# Out:
# История : (28, 3)
#
# Цель для прогнозирования : (7,)

# %%
print ('История:\n')
print (x_train_multi[0])
print ('\nЦель для прогнозирования:\n')
print (y_train_multi[0])
# Out:
# История:
#
# [[0.21021143 0.105323   0.11128283]
#  [0.27061214 0.21021143 0.105323  ]
#  [0.293512   0.27061214 0.21021143]
#  [0.2548113  0.293512   0.27061214]
#  [0.23591523 0.2548113  0.293512  ]
#  [0.16357477 0.23591523 0.2548113 ]
#  [0.2394502  0.16357477 0.23591523]
#  [0.14036389 0.2394502  0.16357477]
#  [0.25830373 0.14036389 0.2394502 ]
#  [0.29157023 0.25830373 0.14036389]
#  [0.28602646 0.29157023 0.25830373]
#  [0.28281226 0.28602646 0.29157023]
#  [0.2797905  0.28281226 0.28602646]
#  [0.35415338 0.2797905  0.28281226]
#  [0.42526266 0.35415338 0.2797905 ]
#  [0.14913935 0.42526266 0.35415338]
#  [0.24844442 0.14913935 0.42526266]
#  [0.44876339 0.24844442 0.14913935]
#  [0.506297   0.44876339 0.24844442]
#  [0.45261563 0.506297   0.44876339]
#  [0.51024942 0.45261563 0.506297  ]
#  [0.36066611 0.51024942 0.45261563]
#  [0.43962259 0.36066611 0.51024942]
#  [0.51288504 0.43962259 0.36066611]
#  [0.52761491 0.51288504 0.43962259]
#  [0.40945299 0.52761491 0.51288504]
#  [0.46402413 0.40945299 0.52761491]
#  [0.46647561 0.46402413 0.40945299]]
#
# Цель для прогнозирования:
#
# [0.45039507 0.461975   0.40451431 0.40735506 0.49622463 0.47671113
#  0.53188792]

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(8, 4))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), 'o-', label='История')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'o-', label='Реальные будущие значения')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'o-', color='b', label='Прогноз')
  plt.legend(loc='best')
  plt.show()

# %%
for col in range(3):
    multi_step_plot(x_train_multi[col], 
                    y_train_multi[col], 
                    np.array([0]), 
)
plt.show()

# %%
multi_step_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(32,  
                         return_sequences=True, 
                         input_shape=x_train_multi.shape[-2:]
                         ),

    tf.keras.layers.LSTM(16, 
                         activation='softmax'
                         ),

    tf.keras.layers.Dense(future_target)
])

multi_step_model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.01), loss='mean_absolute_error')
multi_step_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 28, 32)            4608
#
#  lstm_3 (LSTM)               (None, 16)                3136
#
#  dense_2 (Dense)             (None, 7)                 119
#
# =================================================================
# Total params: 7,863
# Trainable params: 7,863
# Non-trainable params: 0
# _________________________________________________________________

# %%
multi_step_history = multi_step_model.fit(x_train_multi,
                                          y_train_multi, 
                                          epochs=16,
                                          validation_data=(x_val_multi, y_val_multi))
# Out:
# Epoch 1/16
# 6/6 [==============================] - 4s 186ms/step - loss: 0.4337 - val_loss: 0.3256
# Epoch 2/16
# 6/6 [==============================] - 1s 90ms/step - loss: 0.2823 - val_loss: 0.1379
# Epoch 3/16
# 6/6 [==============================] - 1s 188ms/step - loss: 0.2068 - val_loss: 0.1315
# Epoch 4/16
# 6/6 [==============================] - 1s 86ms/step - loss: 0.1883 - val_loss: 0.0824
# Epoch 5/16
# 6/6 [==============================] - 0s 73ms/step - loss: 0.1628 - val_loss: 0.0523
# Epoch 6/16
# 6/6 [==============================] - 0s 82ms/step - loss: 0.1607 - val_loss: 0.0356
# Epoch 7/16
# 6/6 [==============================] - 1s 151ms/step - loss: 0.1578 - val_loss: 0.0421
# Epoch 8/16
# 6/6 [==============================] - 0s 80ms/step - loss: 0.1587 - val_loss: 0.0343
# Epoch 9/16
# 6/6 [==============================] - 1s 92ms/step - loss: 0.1574 - val_loss: 0.0337
# Epoch 10/16
# 6/6 [==============================] - 0s 59ms/step - loss: 0.1572 - val_loss: 0.0342
# Epoch 11/16
# 6/6 [==============================] - 0s 54ms/step - loss: 0.1572 - val_loss: 0.0341
# Epoch 12/16
# 6/6 [==============================] - 0s 57ms/step - loss: 0.1568 - val_loss: 0.0338
# Epoch 13/16
# 6/6 [==============================] - 1s 116ms/step - loss: 0.1571 - val_loss: 0.0327
# Epoch 14/16
# 6/6 [==============================] - 1s 94ms/step - loss: 0.1567 - val_loss: 0.0315
# Epoch 15/16
# 6/6 [==============================] - 1s 98ms/step - loss: 0.1568 - val_loss: 0.0316
# Epoch 16/16
# 6/6 [==============================] - 0s 82ms/step - loss: 0.1566 - val_loss: 0.0315

# %%
plot_loss(multi_step_history)

# %%
y_pred_multi = multi_step_model.predict(x_val_multi)

for col in range(3):
    multi_step_plot(x_val_multi[col], 
                    y_val_multi[col], 
                    y_pred_multi[col], 
)
plt.show()
# Out:
# 1/1 [==============================] - 1s 581ms/step
